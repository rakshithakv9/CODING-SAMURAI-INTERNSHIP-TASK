# %%
pip install pandas textblob nltk
# Out:
# Requirement already satisfied: pandas in c:\users\rakshitha k v\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: textblob in c:\users\rakshitha k v\anaconda3\lib\site-packages (0.20.0)
# Requirement already satisfied: nltk in c:\users\rakshitha k v\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\rakshitha k v\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rakshitha k v\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rakshitha k v\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rakshitha k v\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: click in c:\users\rakshitha k v\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\rakshitha k v\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\rakshitha k v\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\rakshitha k v\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: six>=1.5 in c:\users\rakshitha k v\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in c:\users\rakshitha k v\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_csv("IMDB Dataset.csv")

# %%
from textblob import TextBlob
import pandas as pd

# Load dataset
df = pd.read_csv("IMDB Dataset.csv")

# Function to predict sentiment
def get_sentiment(text):
    polarity = TextBlob(str(text)).sentiment.polarity

    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    else:
        return "Neutral"

# Apply sentiment analysis on review column
df["Predicted_Sentiment"] = df["review"].apply(get_sentiment)

# Display first 5 rows
print(df[["review", "Predicted_Sentiment"]].head())

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x="Predicted_Sentiment", data=df)
plt.show()
